# %%
## Cargamos nuestras librerías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
import jinja2
from pycaret.classification import *
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
sns.set()

# %%
## Cargamos nuestros datos 
data = pd.read_excel('Matriculas IES chilenas.xlsx')
data=data[['Año', 'Cód. Institución', 'Nombre Institución', 'Tipo Institución', 'Clasificación1', 'Clasificación3', 'Clasificación5','Matrícula total hombres','Matrícula total mujeres',
    'Nombre Institución','Nombre Region','Area Conocimiento','Carrera Genérica','Máximo Puntaje (promedio matemáticas y lenguaje)','Puntaje de corte (promedio de la carrera)']]

# %%
data.head()
# Out:
#     Año  Cód. Institución Nombre Institución Tipo Institución  \
# 0  2022              1001        U. DE CHILE            Univ.
# 1  2022              1001        U. DE CHILE            Univ.
# 2  2022              1001        U. DE CHILE            Univ.
# 3  2022              1001        U. DE CHILE            Univ.
# 4  2022              1001        U. DE CHILE            Univ.
#
#             Clasificación1  Clasificación3             Clasificación5  \
# 0  (a) Universidades CRUCH  (a) Acreditada  (a) Adscritas a Gratuidad
# 1  (a) Universidades CRUCH  (a) Acreditada  (a) Adscritas a Gratuidad
# 2  (a) Universidades CRUCH  (a) Acreditada  (a) Adscritas a Gratuidad
# 3  (a) Universidades CRUCH  (a) Acreditada  (a) Adscritas a Gratuidad
# 4  (a) Universidades CRUCH  (a) Acreditada  (a) Adscritas a Gratuidad
#
#    Matrícula total hombres  Matrícula total mujeres Nombre Institución  \
# 0                      291                      401        U. DE CHILE
# ...

# %%
data=data.dropna(subset=['Máximo Puntaje (promedio matemáticas y lenguaje)','Puntaje de corte (promedio de la carrera)'])0
data.isnull().sum()
# Out:
# Año                                                 0
# Cód. Institución                                    0
# Nombre Institución                                  0
# Tipo Institución                                    0
# Clasificación1                                      0
# Clasificación3                                      0
# Clasificación5                                      0
# Matrícula total hombres                             0
# Matrícula total mujeres                             0
# Nombre Institución                                  0
# Nombre Region                                       0
# Area Conocimiento                                   0
# Carrera Genérica                                    0
# Máximo Puntaje (promedio matemáticas y lenguaje)    0
# Puntaje de corte (promedio de la carrera)           0
# dtype: int64

# %%
data["Matrícula total hombres"].value_counts()
# Out:
# 0       537
# 1       312
# 10      269
# 15      263
# 16      261
#        ...
# 1562      1
# 1150      1
# 738       1
# 499       1
# 614       1
# Name: Matrícula total hombres, Length: 853, dtype: int64

# %%
sns.countplot(x='Area Conocimiento',data = data,hue='Clasificación3')
plt.xticks(rotation=90)
plt.title("No. Clientes")
# Out:
# Text(0.5, 1.0, 'No. Clientes')

# %%
data["Máximo Puntaje (promedio matemáticas y lenguaje)"]
# Out:
# 0         779.0
# 1         744.0
# 2         792.0
# 3         779.0
# 4         774.0
#           ...
# 165656    744.0
# 165657    663.0
# 165671    597.0
# 167230    550.0
# 167232    602.0
# Name: Máximo Puntaje (promedio matemáticas y lenguaje), Length: 31468, dtype: float64

# %%
ax = data["Máximo Puntaje (promedio matemáticas y lenguaje)"].value_counts().hist(bins=15, density=True, stacked=True, color='teal', alpha=0.6)
data["Máximo Puntaje (promedio matemáticas y lenguaje)"].value_counts().plot(kind='density', color='teal')
ax.set(xlabel='Area Conocimiento')

plt.xlim(-10,85)
plt.show()

# %%
'''data['Clasificación1']=LabelEncoder().fit_transform(data['Clasificación1'])
data['Clasificación3']=LabelEncoder().fit_transform(data['Clasificación3'])
data['Nombre Region']=LabelEncoder().fit_transform(data['Nombre Region'])
data['Area Conocimiento']=LabelEncoder().fit_transform(data['Area Conocimiento'])
data['Carrera Genérica']=LabelEncoder().fit_transform(data['Carrera Genérica'])
data['Máximo Puntaje (promedio matemáticas y lenguaje)']=data['Máximo Puntaje (promedio matemáticas y lenguaje)'].astype(int)
data.info()'''
# Out:
# "data['Clasificación1']=LabelEncoder().fit_transform(data['Clasificación1'])\ndata['Clasificación3']=LabelEncoder().fit_transform(data['Clasificación3'])\ndata['Nombre Region']=LabelEncoder().fit_transform(data['Nombre Region'])\ndata['Area Conocimiento']=LabelEncoder().fit_transform(data['Area Conocimiento'])\ndata['Carrera Genérica']=LabelEncoder().fit_transform(data['Carrera Genérica'])\ndata['Máximo Puntaje (promedio matemáticas y lenguaje)']=data['Máximo Puntaje (promedio matemáticas y lenguaje)'].astype(int)\ndata.info()"

# %%
train_data=data.sample(frac=0.90,random_state=345)
test_data=data.drop(train_data.index)
train_data.reset_index(inplace=True,drop=True)
test_data.reset_index(inplace=True,drop=True)

# %%
#print the number of word and column of the new data set
print('Data used to train the model has ' +str(train_data.shape[0])+' rows and '+str(train_data.shape[1])+' columns')
print('unseen Data used test for making predictions or classifications has ' +str(test_data.shape[0])+' rows and '+str(test_data.shape[1])+' columns')
# Out:
# Data used to train the model has 28321 rows and 15 columns
# unseen Data used test for making predictions or classifications has 3147 rows and 15 columns

# %%
from pycaret.classification import *
s = setup(data = train_data, target= 'Máximo Puntaje (promedio matemáticas y lenguaje)',  fold_shuffle=True, session_id=345)
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     13:13:03
# Status     . . . . . . . . . . . . . . . . . .  Preparing Data for Modeling
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Users\claud\Downloads\modulo 5\Claudio Alcaman tarea1_modulo5.ipynb Cell 8' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000015?line=0'>1</a> from pycaret.classification import *
# ----> <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000015?line=1'>2</a> s = setup(data = train_data, target= 'Máximo Puntaje (promedio matemáticas y lenguaje)',  fold_shuffle=True, session_id=345)
#
# ...

# %%
model= compare_models()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Users\claud\Downloads\modulo 5\Claudio Alcaman tarea1_modulo5.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000016?line=0'>1</a> model= compare_models()
#
# File c:\Users\claud\anaconda3\lib\site-packages\pycaret\classification.py:771, in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, verbose)
#     658 def compare_models(
#     659     include: Optional[List[Union[str, Any]]] = None,
#     660     exclude: Optional[List[str]] = None,
#    (...)
#     671     verbose: bool = True,
#     672 ) -> Union[Any, List[Any]]:
#     674     """
#     675     This function trains and evaluates performance of all estimators available in the
# ...

# %%
#create random forest model
forest= create_model('rf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Users\claud\Downloads\modulo 5\Claudio Alcaman tarea1_modulo5.ipynb Cell 10' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000017?line=0'>1</a> #create random forest model
# ----> <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000017?line=1'>2</a> forest= create_model('rf')
#
# File c:\Users\claud\anaconda3\lib\site-packages\pycaret\classification.py:889, in create_model(estimator, fold, round, cross_validation, fit_kwargs, groups, verbose, **kwargs)
#     788 def create_model(
#     789     estimator: Union[str, Any],
#     790     fold: Optional[Union[int, Any]] = None,
#    (...)
#     796     **kwargs,
#     797 ) -> Any:
#     799     """
# ...

# %%
y = data['Máximo Puntaje (promedio matemáticas y lenguaje)']
x1 = data[['Nombre Region','Area Conocimiento']]
x = sm.add_constant(x)
model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Users\claud\Downloads\modulo 5\Claudio Alcaman tarea1_modulo5.ipynb Cell 6' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000015?line=1'>2</a> x1 = data[['Nombre Region','Area Conocimiento']]
#       <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000015?line=2'>3</a> x = sm.add_constant(x)
# ----> <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000015?line=3'>4</a> model = sm.OLS(y, x).fit()
#       <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000015?line=4'>5</a> print(model.summary())
#
# ...

# %%
## Definimos nuestra variable dependiente (Y) y nuestra variable independiente
y = data['Máximo Puntaje (promedio matemáticas y lenguaje)']
x1 = data[['Clasificación1']]

# %%
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Users\claud\Downloads\modulo 5\Claudio Alcaman tarea1_modulo5.ipynb Cell 5' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000009?line=0'>1</a> x = sm.add_constant(x1)
# ----> <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000009?line=1'>2</a> results = sm.OLS(y,x).fit()
#       <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000009?line=2'>3</a> results.summary()
#
# File c:\Users\claud\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:890, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     887     msg = ("Weights are not supported in OLS and will be ignored"
# ...

# %%
plt.figure(figsize=(14,14))
sns.heatmap(data.corr(),annot=True,fmt='.0%')
plt.show()

# %%
X1 = data.drop(columns = 'Area Conocimiento', axis = 1)

# %%
plt.figure(figsize = (20, 15))
plotnumber = 1

for column in X1:
    if plotnumber <= 14:
        ax = plt.subplot(3, 5, plotnumber)
        sns.distplot(X1[column])
        plt.xlabel(column, fontsize = 15)
        
    plotnumber += 1
    
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Users\claud\Downloads\modulo 5\Claudio Alcaman tarea1_modulo5.ipynb Cell 6' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000006?line=4'>5</a> if plotnumber <= 14:
#       <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000006?line=5'>6</a>     ax = plt.subplot(3, 5, plotnumber)
# ----> <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000006?line=6'>7</a>     sns.distplot(X1[column])
#       <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000006?line=7'>8</a>     plt.xlabel(column, fontsize = 15)
# ...

# %%
plt.figure(figsize = (20, 8))
sns.boxplot(data = X1, width = 0.8)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Users\claud\Downloads\modulo 5\Claudio Alcaman tarea1_modulo5.ipynb Cell 7' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000007?line=0'>1</a> plt.figure(figsize = (20, 8))
# ----> <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000007?line=1'>2</a> sns.boxplot(data = data, width = 0.8)
#       <a href='vscode-notebook-cell:/d%3A/Users/claud/Downloads/modulo%205/Claudio%20Alcaman%20tarea1_modulo5.ipynb#ch0000007?line=2'>3</a> plt.show()
#
# File c:\Users\claud\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
# ...

# %%
train_data=data.sample(frac=0.90,random_state=345)
test_data=data.drop(train_data.index)
train_data.reset_index(inplace=True,drop=True)
test_data.reset_index(inplace=True,drop=True)
